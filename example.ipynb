# %%
from workflows.potentials import EAM_Ackland_Fe
from workflows.build import bulk
from workflows.evcurves import calculate_ev_curves
from workflows.freenergy import calculate_free_energy, calculate_quasiharmonic_free_energy, calculate_internal_energy
import matplotlib.pyplot as plt

# %%
struct = bulk('Fe', cubic=True)

# %%
calculate_ev_curves(struct, EAM_Ackland_Fe,)
# Out:
# 0it [00:00, ?it/s]
# The job murn_job5 was saved and received the ID: 3398
# The job murn_job5_0_9 was saved and received the ID: 3399
# The job murn_job5_0_95 was saved and received the ID: 3400
# The job murn_job5_1_0 was saved and received the ID: 3401
# The job murn_job5_1_05 was saved and received the ID: 3402
# The job murn_job5_1_1 was saved and received the ID: 3403

# %%
febcc = calculate_free_energy(struct.repeat(5), EAM_Ackland_Fe, temperature=[300, 600])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /home/srmnitc/miniforge3/envs/workflow-rdf/lib/python3.11/site-packages/h5io/_h5io.py:66: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['Config', 'Filename', 'Model', 'Name', 'Species'], dtype='object')]
#
#   data.to_hdf(fname, key=rootpath)
# The job c1 was saved and received the ID: 3404
# /home/srmnitc/miniforge3/envs/workflow-rdf/lib/python3.11/site-packages/ase/io/lammpsdata.py:49: FutureWarning: "style" is deprecated; please use "atom_style".
#   warnings.warn(
# Job 3404 is running!
# /home/srmnitc/miniforge3/envs/workflow-rdf/lib/python3.11/site-packages/ase/io/lammpsdata.py:49: FutureWarning: "style" is deprecated; please use "atom_style".
#   warnings.warn(
# /home/srmnitc/miniforge3/envs/workflow-rdf/lib/python3.11/site-packages/h5io/_h5io.py:66: PerformanceWarning:
# ...

# %%
plt.plot(febcc[0], febcc[1])
plt.xlabel('temperature (K)')
plt.ylabel('free energy (eV/atom)')
# Out:
# Text(0, 0.5, 'free energy (eV/atom)')

# %%
job = calculate_quasiharmonic_free_energy(struct, EAM_Ackland_Fe, temperature=600, temperature_steps=4)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
# 2025-06-12 10:34:52,621 - pyiron_log - WARNING - Could not remove job with ID 3433
# 2025-06-12 10:34:52,622 - pyiron_log - WARNING - Could not remove job with ID 3434
# 2025-06-12 10:34:52,624 - pyiron_log - WARNING - Could not remove job with ID 3435
# 2025-06-12 10:34:52,625 - pyiron_log - WARNING - Could not remove job with ID 3436
# 2025-06-12 10:34:52,627 - pyiron_log - WARNING - Could not remove job with ID 3437
# 2025-06-12 10:34:52,628 - pyiron_log - WARNING - Could not remove job with ID 3438
# 2025-06-12 10:34:52,629 - pyiron_log - WARNING - Could not remove job with ID 3439
# 2025-06-12 10:34:52,630 - pyiron_log - WARNING - Could not remove job with ID 3440
# 2025-06-12 10:34:52,631 - pyiron_log - WARNING - Could not remove job with ID 3441
# 2025-06-12 10:34:52,633 - pyiron_log - WARNING - Could not remove job with ID 3442
# 2025-06-12 10:34:52,634 - pyiron_log - WARNING - Could not remove job with ID 3443
# ...

# %%
plt.plot(job[0], job[1])
plt.xlabel('temperature (K)')
plt.ylabel('free energy (eV/atom)')
# Out:
# Text(0, 0.5, 'free energy (eV/atom)')
