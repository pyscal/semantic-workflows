# %%
from semantic_workflows.pyiron.elastic import calculate_elastic_constants
from semantic_workflows.pyiron.build import bulk
from pyiron_workflow import Workflow
from conceptual_dictionary import ConceptualDict

# %%
pair_style = "eam/alloy"
pair_coeff = "* * semantic_workflows/potentials/Fe_Ack.eam Fe"

# %%
cd = ConceptualDict()

# %%
wf = Workflow('e1')
wf.structure = bulk('Fe', cubic=True, cdict=cd)
wf.elastic = calculate_elastic_constants(wf.structure, pair_style, pair_coeff, cdict=cd)

# %%
wf.draw(rankdir='LR', size=(10, 10))

# %%
wf.run()
# Out:
# {'elastic__results': {'C_matrix': array([[ 2.43442065e+02,  1.45084473e+02,  1.45084473e+02,
#            1.85593079e-09, -3.99662012e-09,  5.83134734e-09],
#          [ 1.45084473e+02,  2.43442065e+02,  1.45084473e+02,
#            1.01480647e-09, -2.91461865e-09,  2.11221384e-09],
#          [ 1.45084473e+02,  1.45084473e+02,  2.43442065e+02,
#            9.20405769e-10,  3.84682979e-09,  2.76121761e-09],
#          [ 1.85593079e-09,  1.01480647e-09,  9.20405769e-10,
#            1.16053046e+02,  1.88801198e-10,  5.31003369e-10],
#          [-3.99662012e-09, -2.91461865e-09,  3.84682979e-09,
#            1.88801198e-10,  1.16053046e+02, -3.30402096e-10],
#          [ 5.83134734e-09,  2.11221384e-09,  2.76121761e-09,
#            5.31003369e-10, -3.30402096e-10,  1.16053046e+02]]),
#   'Bulk_modulus': 177.87033669302664,
#   'Shear_modulus1': 116.053045768637,
#   'Shear_modulus2': 49.178796204002495,
#   'Poisson_ratio': 0.373422298209911}}

# %%
cd.to_yaml('elastic.yaml')
